# %%
print(spark)
filePath = "/FileStore/tables/customers.csv"
read = spark.read.format('csv').options(header='true').options(inferSchema='true').load(filePath)
print(read)
read.show()
read.write.format("json").mode("overwrite").save("/FileStore/tables/customers.json")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;pyspark.sql.session.SparkSession object at 0x7f06d08f7c50&gt;
# DataFrame[id: int, name: string, active: int]
# +---+-----+------+
#  id| name|active|
# +---+-----+------+
#   1|Cust1|     1|
#   2|Cust2|     0|
#   3|Cust3|     1|
# +---+-----+------+
#
# </div>

# %%
# %fs ls /FileStore/tables/customers.json
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/customers.json/_SUCCESS</td><td>_SUCCESS</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/customers.json/_committed_1916392630138732033</td><td>_committed_1916392630138732033</td><td>199</td></tr><tr><td>dbfs:/FileStore/tables/customers.json/_committed_4830268700400570610</td><td>_committed_4830268700400570610</td><td>210</td></tr><tr><td>dbfs:/FileStore/tables/customers.json/_committed_6685263526448070280</td><td>_committed_6685263526448070280</td><td>112</td></tr><tr><td>dbfs:/FileStore/tables/customers.json/_started_1916392630138732033</td><td>_started_1916392630138732033</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/customers.json/_started_4830268700400570610</td><td>_started_4830268700400570610</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/customers.json/_started_6685263526448070280</td><td>_started_6685263526448070280</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/customers.json/part-00000-tid-1916392630138732033-4bcbca95-0ce1-4966-94bc-a7d2a232d6ae-9-1-c000.json</td><td>part-00000-tid-1916392630138732033-4bcbca95-0ce1-4966-94bc-a7d2a232d6ae-9-1-c000.json</td><td>105</td></tr></tbody></table></div>

# %%
dbutils.fs.head("dbfs:/FileStore/tables/customers.json/part-00000-tid-6685263526448070280-7b37ea46-0a40-43cc-8bde-2ac6660b59d3-2-1-c000.json")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: &#39;{&#34;id&#34;:1,&#34;name&#34;:&#34;Cust1&#34;,&#34;active&#34;:1}\n{&#34;id&#34;:2,&#34;name&#34;:&#34;Cust2&#34;,&#34;active&#34;:0}\n{&#34;id&#34;:3,&#34;name&#34;:&#34;Cust3&#34;,&#34;active&#34;:1}\n&#39;</div>

# %%
dbutils.fs.rm("/FileStore/tables/applications.json")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[13]: True</div>

# %%
filePath = "/FileStore/tables/applications.json"
read = spark.read.format('json').option("multiline","true").load(filePath)
print(read)
read.show()

print(type(read))

def printDetails(row):
  print("printDetails:", row)
  
read.foreach(printDetails)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame[active: bigint, id: bigint, name: string]
# +------+---+----+
# active| id|name|
# +------+---+----+
#      1|  1| OMS|
#      1|  2| TMS|
# +------+---+----+
#
# &lt;class &#39;pyspark.sql.dataframe.DataFrame&#39;&gt;
# </div>
